# %% [markdown]
# # Atividade 03 - Introdução ao Pandas - Diogo Lima Carvalho - DSM6

# %%
import pandas as pd

# %% [markdown]
# **Criar um DataFrame com o nome frutas no seguinte formato:**

# %%
frutas = pd.DataFrame([[30,20]], columns=['Maça', 'Banana'])

# %%
frutas.head()
# Out:
#    Maça  Banana
# 0    30      20

# %% [markdown]
# **Criar um DataFrame com o nome vendas_frutas no seguinte formato:**

# %%
vendas_frutas = pd.DataFrame([[1000, 700], [5000, 2000]], columns=['Maça', 'Banana'], index=['Vendas 2022', 'Vendas 2023'])

# %%
vendas_frutas.head()
# Out:
#              Maça  Banana
# Vendas 2022  1000     700
# Vendas 2023  5000    2000

# %% [markdown]
# **Utilizar o site https://www.kaggle.com/ para obter um arquivo CSV para demonstração dos seguintes comandos:**
#
# Database retirada: https://www.kaggle.com/datasets/rezaghari/friends-series-dataset

# %% [markdown]
# **Importação arquivo .CSV**

# %%
friends_data = pd.read_csv('friends_data.csv')

# %%
friends_data.head()
# Out:
#    Year_of_prod  Season                                   Episode_Title  \
# 0          1994       1            The One with the Sonogram at the End
# 1          1994       1                          The One with the Thumb
# 2          1994       1              The One with George Stephanopoulos
# 3          1994       1  The One with the East German Laundry Detergent
# 4          1994       1                           The One with the Butt
#
#    Duration                                            Summary  \
# 0        22  Ross finds out his ex-wife is pregnant. Rachel...
# 1        22  Monica becomes irritated when everyone likes h...
# 2        22  Joey and Chandler take Ross to a hockey game t...
# 3        22  Eager to spend time with Rachel, Ross pretends...
# 4        22  Monica's obsessiveness is put to the test afte...
#
#          Director  Stars  Votes
# 0   James Burrows    8.1   4888
# 1   James Burrows    8.2   4605
# 2   James Burrows    8.1   4468
# ...

# %% [markdown]
# **Tipo de dados de cada coluna**

# %%
friends_data.dtypes
# Out:
# Year_of_prod       int64
# Season             int64
# Episode_Title     object
# Duration           int64
# Summary           object
# Director          object
# Stars            float64
# Votes              int64
# dtype: object

# %% [markdown]
# **Realizar a leitura de valores de uma coluna em específico**

# %%
friends_data['Episode_Title'].unique()
# Out:
# array(['The One with the Sonogram at the End', 'The One with the Thumb',
#        'The One with George Stephanopoulos',
#        'The One with the East German Laundry Detergent',
#        'The One with the Butt', 'The One with the Blackout',
#        'The One Where Nana Dies Twice',
#        'The One Where Underdog Gets Away', 'The One with the Monkey',
#        'The One with Mrs. Bing', 'The One with the Dozen Lasagnas',
#        'The One with the Boobies', 'The One with the Candy Hearts',
#        'The One with the Stoned Guy', 'The One with Two Parts: Part 1',
#        'The One with Two Parts: Part 2', 'The One with All the Poker',
#        'The One Where the Monkey Gets Away',
#        'The One with the Evil Orthodontist',
#        'The One with the Fake Monica', 'The One with the Ick Factor',
#        'The One with the Birth', 'The One Where Rachel Finds Out',
#        "The One with Ross's New Girlfriend",
#        'The One with the Breast Milk', 'The One Where Heckles Dies',
# ...

# %% [markdown]
# **Obter o valor máximo de uma coluna**

# %%
friends_data.max()
# Out:
# Year_of_prod                                                  2004
# Season                                                          10
# Episode_Title                                The One with the Yeti
# Duration                                                        30
# Summary          at first Ross chooses Joey to be his best man ...
# Director                                              Todd Holland
# Stars                                                          9.7
# Votes                                                        10381
# dtype: object

# %% [markdown]
# **Verificar os dados de uma coluna com um determinado valor**

# %%
num_ep_of_year = pd.to_numeric(friends_data['Year_of_prod'], errors='coerce')

# %%
results_numbers_yeard = friends_data.loc[num_ep_of_year >= 2004]

# %%
results_numbers_yeard.count()
# Out:
# Year_of_prod     10
# Season           10
# Episode_Title    10
# Duration         10
# Summary          10
# Director         10
# Stars            10
# Votes            10
# dtype: int64

# %%
results_numbers_yeard.head(10)
# Out:
#      Year_of_prod  Season                           Episode_Title  Duration  \
# 225          2004      10           The One with the Birth Mother        22
# 226          2004      10      The One Where Chandler Gets Caught        22
# 227          2004      10        The One Where the Stripper Cries        22
# 228          2004      10           The One with Phoebe's Wedding        22
# 229          2004      10        The One Where Joey Speaks French        22
# 230          2004      10          The One with Princess Consuela        22
# 231          2004      10              The One Where Estelle Dies        22
# 232          2004      10  The One with Rachel's Going Away Party        22
# 233          2004      10                            The Last One        30
# 234          2004      10                            The Last One        30
#
#                                                Summary         Director  \
# ...
